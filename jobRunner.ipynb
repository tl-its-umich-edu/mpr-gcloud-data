# %%
from google.cloud import aiplatform
from datetime import datetime
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

def get_timestamp():
    return datetime.now().strftime("%Y%m%d%H%M%S")

PROJECT_ID = 'mwrite-a835'

PACKAGE_NAME = 'mpr-research-trainer'
PACKAGE_VERSION = '0.0.3'
PACKAGE_GCS_BUCKET_NAME = 'mpr-research-package'

source_package_file_name = f"./dist/{PACKAGE_NAME}-{PACKAGE_VERSION}.tar.gz"
python_package_gcs_uri = (
    f"gs://{PACKAGE_GCS_BUCKET_NAME}/trainer-{PACKAGE_VERSION}.tar.gz"
)
python_module_name = "trainer.task"

PRE_BUILT_TRAINING_CONTAINER_IMAGE_URI = (
    'us-docker.pkg.dev/vertex-ai/training/pytorch-gpu.1-11:latest'
)

aiplatform.init(project=PROJECT_ID, staging_bucket=PACKAGE_GCS_BUCKET_NAME)

# %%
# %%writetemplate ./setup.cfg
# [options]
#
# package_dir =
#     = src
# python_requires = >=3.7
# packages = find:
#
# install_requires =
#     transformers == 4.19
#     datasets == 2.2
#     torch == 1.11
#     tqdm == 4.64
#     openpyxl == 3.0
#     cloudml-hypertune == 0.1.0.dev6
#
#
# include_package_data = True
#
# [options.packages.find]
# where = src
#
# [metadata]
# name = {PACKAGE_NAME}
# version = {PACKAGE_VERSION}
# # author = Kapotaksha
# # author_email = takposha@umich.edu
# description = Used to train and tune MWrite data using PeerBERT
# long_description = file: README.md
# long_description_content_type = text/markdown
# # url = https://github.com/pypa/sampleproject
# # project_urls =
# #    Bug Tracker = https://github.com/pypa/sampleproject/issues
# classifiers =
#     Programming Language :: Python :: 3
#     Operating System :: OS Independent

# %%
# !python -m build
# Out:
# * Creating virtualenv isolated environment...
# * Installing packages in isolated environment... (setuptools>=42)
# * Getting dependencies for sdist...
# running egg_info
# creating src/mpr_research_trainer.egg-info
# writing src/mpr_research_trainer.egg-info/PKG-INFO
# writing dependency_links to src/mpr_research_trainer.egg-info/dependency_links.txt
# writing requirements to src/mpr_research_trainer.egg-info/requires.txt
# writing top-level names to src/mpr_research_trainer.egg-info/top_level.txt
# writing manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# reading manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# writing manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing src/mpr_research_trainer.egg-info/PKG-INFO
# writing dependency_links to src/mpr_research_trainer.egg-info/dependency_links.txt
# writing requirements to src/mpr_research_trainer.egg-info/requires.txt
# writing top-level names to src/mpr_research_trainer.egg-info/top_level.txt
# reading manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# writing manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# running check
# creating mpr-research-trainer-0.0.3
# creating mpr-research-trainer-0.0.3/src
# creating mpr-research-trainer-0.0.3/src/mpr_research_trainer.egg-info
# creating mpr-research-trainer-0.0.3/src/trainer
# copying files to mpr-research-trainer-0.0.3...
# copying README.md -> mpr-research-trainer-0.0.3
# copying pyproject.toml -> mpr-research-trainer-0.0.3
# copying setup.cfg -> mpr-research-trainer-0.0.3
# copying src/mpr_research_trainer.egg-info/PKG-INFO -> mpr-research-trainer-0.0.3/src/mpr_research_trainer.egg-info
# copying src/mpr_research_trainer.egg-info/SOURCES.txt -> mpr-research-trainer-0.0.3/src/mpr_research_trainer.egg-info
# copying src/mpr_research_trainer.egg-info/dependency_links.txt -> mpr-research-trainer-0.0.3/src/mpr_research_trainer.egg-info
# copying src/mpr_research_trainer.egg-info/requires.txt -> mpr-research-trainer-0.0.3/src/mpr_research_trainer.egg-info
# copying src/mpr_research_trainer.egg-info/top_level.txt -> mpr-research-trainer-0.0.3/src/mpr_research_trainer.egg-info
# copying src/trainer/__init__.py -> mpr-research-trainer-0.0.3/src/trainer
# copying src/trainer/task.py -> mpr-research-trainer-0.0.3/src/trainer
# Writing mpr-research-trainer-0.0.3/setup.cfg
# Creating tar archive
# removing 'mpr-research-trainer-0.0.3' (and everything under it)
# * Building wheel from sdist
# * Creating virtualenv isolated environment...
# * Installing packages in isolated environment... (setuptools>=42)
# * Getting dependencies for wheel...
# running egg_info
# writing src/mpr_research_trainer.egg-info/PKG-INFO
# writing dependency_links to src/mpr_research_trainer.egg-info/dependency_links.txt
# writing requirements to src/mpr_research_trainer.egg-info/requires.txt
# writing top-level names to src/mpr_research_trainer.egg-info/top_level.txt
# reading manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# writing manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# * Installing packages in isolated environment... (wheel)
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/trainer
# copying src/trainer/__init__.py -> build/lib/trainer
# copying src/trainer/task.py -> build/lib/trainer
# running egg_info
# writing src/mpr_research_trainer.egg-info/PKG-INFO
# writing dependency_links to src/mpr_research_trainer.egg-info/dependency_links.txt
# writing requirements to src/mpr_research_trainer.egg-info/requires.txt
# writing top-level names to src/mpr_research_trainer.egg-info/top_level.txt
# reading manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# writing manifest file 'src/mpr_research_trainer.egg-info/SOURCES.txt'
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/trainer
# copying build/lib/trainer/__init__.py -> build/bdist.linux-x86_64/wheel/trainer
# copying build/lib/trainer/task.py -> build/bdist.linux-x86_64/wheel/trainer
# running install_egg_info
# Copying src/mpr_research_trainer.egg-info to build/bdist.linux-x86_64/wheel/mpr_research_trainer-0.0.3-py3.7.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/mpr_research_trainer-0.0.3.dist-info/WHEEL
# creating '/home/jupyter/mpr-gcloud-data/dist/tmpezo68c19/mpr_research_trainer-0.0.3-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'trainer/__init__.py'
# adding 'trainer/task.py'
# adding 'mpr_research_trainer-0.0.3.dist-info/METADATA'
# adding 'mpr_research_trainer-0.0.3.dist-info/WHEEL'
# adding 'mpr_research_trainer-0.0.3.dist-info/top_level.txt'
# adding 'mpr_research_trainer-0.0.3.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built mpr-research-trainer-0.0.3.tar.gz and mpr_research_trainer-0.0.3-py3-none-any.whl

# %%
# !gsutil cp {source_package_file_name} {python_package_gcs_uri}
# !gsutil ls -l {python_package_gcs_uri}
# Out:
# Copying file://./dist/mpr-research-trainer-0.0.3.tar.gz [Content-Type=application/x-tar]...
# / [1 files][  6.0 KiB/  6.0 KiB]
# Operation completed over 1 objects/6.0 KiB.
#       6177  2022-07-18T15:29:12Z  gs://mpr-research-package/trainer-0.0.3.tar.gz
# TOTAL: 1 objects, 6177 bytes (6.03 KiB)

# %%
for tierLevel in [1,2]:
    JOB_NAME = f"{PACKAGE_NAME}-tierLevel-{tierLevel}-pytorch-pkg-ar-{get_timestamp()}"

    job = aiplatform.CustomPythonPackageTrainingJob(
        display_name=f"{JOB_NAME}",
        python_package_gcs_uri=python_package_gcs_uri,
        python_module_name=python_module_name,
        container_uri=PRE_BUILT_TRAINING_CONTAINER_IMAGE_URI,
    )

    training_args = ['--tier-level', str(tierLevel), '--hidden-layers', '-1' ]

    model = job.run(
        replica_count=1,
        machine_type='n1-standard-8',
        accelerator_type='NVIDIA_TESLA_V100',
        accelerator_count=1,
        args=training_args,
        sync=False,
    )
# Out:
# Training Output directory:
# gs://mpr-research-package/aiplatform-custom-training-2022-07-18-15:29:17.429
# Training Output directory:
# gs://mpr-research-package/aiplatform-custom-training-2022-07-18-15:29:17.437
# View Training:
# https://console.cloud.google.com/ai/platform/locations/us-central1/training/6184632234838851584?project=824680261042
# View Training:
# https://console.cloud.google.com/ai/platform/locations/us-central1/training/8976864003808559104?project=824680261042
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# View backing custom job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/training/4848769587556122624?project=824680261042
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# View backing custom job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/training/3143136781805813760?project=824680261042
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob run completed. Resource name: projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584
# Training did not produce a Managed Model returning None. Training Pipeline projects/824680261042/locations/us-central1/trainingPipelines/6184632234838851584 is not configured to upload a Model. Create the Training Pipeline with model_serving_container_image_uri and model_display_name passed in. Ensure that your training script saves to model to os.environ['AIP_MODEL_DIR'].
# CustomPythonPackageTrainingJob projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# CustomPythonPackageTrainingJob run completed. Resource name: projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104
# Training did not produce a Managed Model returning None. Training Pipeline projects/824680261042/locations/us-central1/trainingPipelines/8976864003808559104 is not configured to upload a Model. Create the Training Pipeline with model_serving_container_image_uri and model_display_name passed in. Ensure that your training script saves to model to os.environ['AIP_MODEL_DIR'].
